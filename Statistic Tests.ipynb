# %%
from sklearn.svm import SVC
from sklearn.metrics import classification_report,confusion_matrix, ConfusionMatrixDisplay
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt
import statistics as st

# %%
healthData = pd.read_csv('healthData.csv')

# %%
healthData.head()
# Out:
#    _id ReferenceID  ReportYear     DiagnosisCategory DiagnosisSubCategory  \
# 0    1  MN25-43524        2025       Autism Spectrum    Autistic Disorder
# 1    2  MN25-43522        2025   Endocrine/Metabolic              Obesity
# 2    3  MN25-43521        2025        Skin Disorders            Psoriasis
# 3    4  MN25-43520        2025  Digestive System/ GI      Crohn's Disease
# 4    5  MN25-43519        2025    CNS/ Neuromusc Dis                Other
#
#     TreatmentCategory  TreatmentSubCategory  \
# 0   Autism Related Tx  Appld Behav Analysis
# 1            Pharmacy        Weight Control
# 2            Pharmacy             Biologics
# 3            Pharmacy       Digestion/GI Rx
# 4  Acute Med Svc Inpt       Early Discharge
#
#                         Determination               Type  AgeRange  \
# 0  Overturned Decision of Health Plan  Medical Necessity   0 to 10
# 1      Upheld Decision of Health Plan  Medical Necessity  51 to 64
# 2  Overturned Decision of Health Plan  Medical Necessity       65+
# 3  Overturned Decision of Health Plan  Medical Necessity  51 to 64
# 4  Overturned Decision of Health Plan  Medical Necessity  41 to 50
#
#   PatientGender   IMRType  DaysToReview  DaysToAdopt  \
# 0        Female  Standard          11.0           45
# 1        Female  Standard          20.0           80
# 2          Male  Standard          13.0           56
# 3        Female  Standard          18.0           54
# 4        Female  Standard          14.0           66
#
#                                             Findings
# 0  Nature of Statutory Criteria/Case Summary: A p...
# 1  Findings:  The physician reviewer found that N...
# 2  Findings:  The physician reviewer found that A...
# 3  Nature of Statutory Criteria/Case Summary: The...
# 4  Findings:  The physician reviewer found that N...

# %%
healthData.describe()

#initial overview before we realized there are duplicates and null values, looked at mean, median, mode
# Out:
#                 _id    ReportYear  DaysToReview   DaysToAdopt
# count  39447.000000  39447.000000  38764.000000  39447.000000
# mean   19724.000000   2015.205263     16.314415     37.501559
# std    11387.512371      6.067554     10.201466     21.602859
# min        1.000000   2001.000000      0.000000      1.000000
# 25%     9862.500000   2010.000000      7.000000     24.000000
# 50%    19724.000000   2016.000000     18.000000     36.000000
# 75%    29585.500000   2020.000000     21.000000     46.000000
# max    39447.000000   2025.000000    133.000000    636.000000

# %%
duplicate = healthData[healthData.duplicated(subset = ['ReferenceID'])]
print(duplicate)

#shows us what rows had duplicates
# Out:
#          _id ReferenceID  ReportYear     DiagnosisCategory  \
# 171      172  MN24-43230        2024   Endocrine/Metabolic
# 172      173  MN24-43230        2024   Endocrine/Metabolic
# 173      174  MN24-43230        2024   Endocrine/Metabolic
# 16581  16582  MN17-26789        2017      Genetic Diseases
# 20077  20078  EI16-23294        2016                Cancer
# 20900  20901  MN16-22472        2016  Digestive System/ GI
# 22426  22427  EI15-20947        2015       Mental Disorder
# 22757  22758  MN15-20615        2015        Skin Disorders
# 23003  23004  EI15-20370        2015                Vision
# 24228  24229  EI14-19144        2014        Not Applicable
# 25643  25644  UR13-15728        2013       Mental Disorder
# 26186  26187  MN13-15159        2013       Mental Disorder
# 27884  27885  MN12-13451        2012                Cancer
# 27921  27922  MN12-13415        2012       Autism Spectrum
# 27933  27934  MN12-13404        2012                Cancer
# 30244  30245  MN10-11087        2010  Cardiac/Circ Problem
# 31875  31876   MN09-9451        2009       Autism Spectrum
# 32157  32158   EI09-9170        2009       Autism Spectrum
# 32174  32175   MN09-9154        2009  Orth/Musculoskeletal
# 32693  32694   MN08-8636        2008       Mental Disorder
# 37795  37796   MN04-3488        2004       Mental Disorder
# 38038  38039   MN03-3246        2003    CNS/ Neuromusc Dis
# 38128  38129   EI03-3155        2003                Cancer
# 38316  38317   MN03-2966        2003                Cancer
# 38348  38349   MN03-2934        2003  Digestive System/ GI
# 38477  38478   MN02-2799        2002       Mental Disorder
# 38600  38601   MN03-2676        2003  Orth/Musculoskeletal
# 38603  38604   EI03-2674        2003        Morbid Obesity
# 38845  38846   EI02-1277        2002    CNS/ Neuromusc Dis
# 38851  38852   EI03-1270        2003       Mental Disorder
# 38935  38936   MN02-1174        2002  Orth/Musculoskeletal
# 39233  39234    EI02-846        2002        Morbid Obesity
# 39332  39333    MN02-732        2002        Morbid Obesity
# 39377  39378    MN02-680        2002  Orth/Musculoskeletal
#
#       DiagnosisSubCategory    TreatmentCategory  TreatmentSubCategory  \
# 171               Diabetes             Pharmacy        Weight Control
# 172               Diabetes             Pharmacy        Weight Control
# 173               Diabetes             Pharmacy        Weight Control
# 16581                Other  Rehab/Svcs SNF Inpt                 Other
# 20077                Other   Diag Imag & Screen              Lab Work
# 20900    Incisional Hernia        Gen Surg Proc         Hernia Repair
# 22426  Depression - Severe   Diag Imag & Screen           Sleep Study
# 22757                 Acne             Pharmacy   Anti-Acne Treatment
# 23003                Other      Vision Services                 Other
# 24228       Not Applicable   Diag Imag & Screen              Lab Work
# 25643      Substance Abuse        Mental Health    Drug Rehab Program
# 26186           Depression        Mental Health    Acute Psych/ Admit
# 27884               Breast  Reconstr/Plast Proc                 Other
# 27921       Autism-PDD-NOS    Autism Related Tx        Speech Therapy
# 27933                Other          Cancer Care                 Other
# 30244          Stroke/ CVA  Rehab/Svcs SNF Inpt        Inpt Admission
# 31875       Autism-PDD-NOS   Rehab/ Svc - Outpt  Occupational Therapy
# 32157       Autism-PDD-NOS        Mental Health    Behavioral Therapy
# 32174     Shoulder Problem   Diag Imag & Screen                   MRI
# 32693                 ADHD   Rehab/ Svc - Outpt  Occupational Therapy
# 37795           Depression        Mental Health         Pyschotherapy
# 38038   Multiple Sclerosis   Rehab/ Svc - Outpt                 Other
# 38128                Colon          Cancer Care          Chemotherapy
# 38316         Throat/ Neck          Cancer Care    Radiation Oncology
# 38348      Irritable Bowel             Pharmacy  Non-FDA Approved Use
# 38477                Other        Mental Health             Inpatient
# 38600                Other       Alternative Tx           Acupuncture
# 38603                Other        Gen Surg Proc        Gastric Bypass
# 38845             Headache             Pharmacy       Botox Injection
# 38851                  ADD   Diag Imag & Screen                 Other
# 38935             Fracture   Rehab/ Svc - Outpt      Physical Therapy
# 39233                Other        Gen Surg Proc        Gastric Bypass
# 39332                Other             Pharmacy        Weight Control
# 39377                Other   Diag Imag & Screen                   MRI
#
#                             Determination                          Type  \
# 171    Overturned Decision of Health Plan             Medical Necessity
# 172    Overturned Decision of Health Plan             Medical Necessity
# 173    Overturned Decision of Health Plan             Medical Necessity
# 16581  Overturned Decision of Health Plan             Medical Necessity
# 20077      Upheld Decision of Health Plan  Experimental/Investigational
# 20900  Overturned Decision of Health Plan             Medical Necessity
# 22426      Upheld Decision of Health Plan  Experimental/Investigational
# 22757  Overturned Decision of Health Plan             Medical Necessity
# 23003  Overturned Decision of Health Plan  Experimental/Investigational
# 24228      Upheld Decision of Health Plan  Experimental/Investigational
# 25643      Upheld Decision of Health Plan                   Urgent Care
# 26186  Overturned Decision of Health Plan             Medical Necessity
# 27884      Upheld Decision of Health Plan             Medical Necessity
# 27921  Overturned Decision of Health Plan             Medical Necessity
# 27933      Upheld Decision of Health Plan             Medical Necessity
# 30244      Upheld Decision of Health Plan             Medical Necessity
# 31875  Overturned Decision of Health Plan             Medical Necessity
# 32157  Overturned Decision of Health Plan  Experimental/Investigational
# 32174      Upheld Decision of Health Plan             Medical Necessity
# 32693  Overturned Decision of Health Plan             Medical Necessity
# 37795      Upheld Decision of Health Plan             Medical Necessity
# 38038      Upheld Decision of Health Plan             Medical Necessity
# 38128      Upheld Decision of Health Plan  Experimental/Investigational
# 38316      Upheld Decision of Health Plan             Medical Necessity
# 38348      Upheld Decision of Health Plan             Medical Necessity
# 38477      Upheld Decision of Health Plan             Medical Necessity
# 38600      Upheld Decision of Health Plan             Medical Necessity
# 38603      Upheld Decision of Health Plan  Experimental/Investigational
# 38845      Upheld Decision of Health Plan  Experimental/Investigational
# 38851      Upheld Decision of Health Plan  Experimental/Investigational
# 38935  Overturned Decision of Health Plan             Medical Necessity
# 39233      Upheld Decision of Health Plan  Experimental/Investigational
# 39332      Upheld Decision of Health Plan             Medical Necessity
# 39377      Upheld Decision of Health Plan             Medical Necessity
#
#        AgeRange PatientGender    IMRType  DaysToReview  DaysToAdopt  \
# 171    41 to 50        Female   Standard          21.0           46
# 172    41 to 50        Female   Standard          21.0           46
# 173    41 to 50        Female   Standard          21.0           46
# 16581  31 to 40          Male  Expedited           3.0           26
# 20077  41 to 50          Male   Standard          21.0           48
# 20900  31 to 40        Female   Standard          21.0           87
# 22426  11 to 20        Female   Standard          54.0           83
# 22757  51 to 64        Female   Standard          10.0           55
# 23003  41 to 50        Female   Standard          27.0           45
# 24228  51 to 64        Female   Standard          19.0           43
# 25643  11 to 20          Male   Standard          31.0           85
# 26186  11 to 20          Male  Expedited           3.0           49
# 27884  21 to 30        Female   Standard           7.0           43
# 27921   0 to 10          Male   Standard          19.0           51
# 27933  51 to 64        Female   Standard          21.0           43
# 30244  51 to 64          Male  Expedited           4.0           35
# 31875   0 to 10        Female   Standard          38.0          109
# 32157   0 to 10        Female   Standard          21.0          148
# 32174  51 to 64        Female   Standard          13.0           36
# 32693   0 to 10          Male   Standard          15.0           52
# 37795  51 to 64          Male   Standard          22.0           51
# 38038  41 to 50        Female   Standard          27.0           56
# 38128  51 to 64          Male  Expedited           7.0           31
# 38316  41 to 50          Male  Expedited           2.0           13
# 38348  31 to 40          Male   Standard          19.0           35
# 38477  11 to 20        Female   Standard         116.0           67
# 38600  51 to 64        Female   Standard          21.0           60
# 38603  31 to 40          Male  Expedited           4.0           32
# 38845       NaN           NaN   Standard          21.0           55
# 38851       NaN           NaN   Standard          21.0           68
# 38935       NaN           NaN   Standard          24.0           51
# 39233       NaN           NaN   Standard          28.0           53
# 39332       NaN           NaN   Standard          21.0           56
# 39377       NaN           NaN   Standard          20.0           39
#
#                                                 Findings
# 171    Nature of Statutory Criteria/Case Summary: A p...
# 172    Nature of Statutory Criteria/Case Summary: A p...
# 173    Nature of Statutory Criteria/Case Summary: A p...
# 16581  Nature of Statutory Criteria/Case Summary: The...
# 20077  Nature of Statutory Criteria/Case Summary: An ...
# 20900  Nature of Statutory Criteria/Case Summary: An ...
# 22426  Nature of Statutory Criteria/Case Summary:   A...
# 22757  Nature of Statutory Criteria/Case Summary:   A...
# 23003  ANature of Statutory Criteria/Case Summary: An...
# 24228  A 62-year-old female enrollee requested genoty...
# 25643  An 18-year-old male enrollee has requested psy...
# 26186  The parent of a 16-year-old male enrollee has ...
# 27884  A 27-year-old female enrollee has requested fo...
# 27921  The parent of an eight-year-old male enrollee ...
# 27933  A 58-year-old female enrollee has requested fo...
# 30244  The representative of a 53-year-old male enrol...
# 31875  The parent of a ten-year-old female enrollee h...
# 32157  The parent of a five-year-old female enrollee ...
# 32174  A 56-year-old female enrollee has requested a ...
# 32693  The parent of a five-year-old male enrollee ha...
# 37795  The patient is a 57-year-old man who has reque...
# 38038  A 45-year-old female enrollee requested author...
# 38128  A 55-year-old male enrollee requested authoriz...
# 38316  A 49-year-old male enrollee requested authoriz...
# 38348  A 32-year-old male enrollee requested authoriz...
# 38477  The mother of a 16-year-old female enrollee re...
# 38600  A 55-year-old female enrollee requested author...
# 38603  A 36-year-old male enrollee requested authoriz...
# 38845  A 47-year-old female enrollee requested author...
# 38851  A 55-year-old female enrollee requested author...
# 38935  A 42-year-old female enrollee requested author...
# 39233  A 53-year-old female enrollee requested author...
# 39332  A 36-year-old male enrollee requested authoriz...
# 39377  A 46-year-old female enrollee requested author...

# %%
healthData.isnull().sum()
#the null values at the beginning
# Out:
# _id                       0
# ReferenceID               0
# ReportYear                0
# DiagnosisCategory         0
# DiagnosisSubCategory      2
# TreatmentCategory         0
# TreatmentSubCategory      1
# Determination             0
# Type                      0
# AgeRange                691
# PatientGender           691
# IMRType                   0
# DaysToReview            683
# DaysToAdopt               0
# Findings                  0
# dtype: int64

# %%
healthDataclean = healthData.drop_duplicates(subset = ['ReferenceID'], keep = 'first')
#dropped all duplicates but kept the first occurrance

# %%
def age(group):
    modeAge = group['AgeRange'].mode()
    if not modeAge.empty:
        group['AgeRange'] = group['AgeRange'].fillna(modeAge[0])
    return group

def gender(group):
    modeGender = group['PatientGender'].mode()
    if not modeGender.empty:
        group['PatientGender'] = group['PatientGender'].fillna(modeGender[0])
    return group

def days(group):
    modeDays = group['DaysToReview'].mode()
    if not modeDays.empty:
        group['DaysToReview'] = group['DaysToReview'].fillna(modeDays[0])
    return group


def DSubCategory(group):
    modeSub = group['DiagnosisSubCategory'].mode()
    if not modeSub.empty:
        group['DiagnosisSubCategory'] = group['DiagnosisSubCategory'].fillna(modeSub[0])
    return group

def TSubCategory(group):
    modeTreat = group['TreatmentSubCategory'].mode()
    if not modeTreat.empty:
        group['TreatmentSubCategory'] = group['TreatmentSubCategory'].fillna(modeTreat[0])
    return group

healthDataclean = healthDataclean.groupby(['DiagnosisCategory']).apply(age).reset_index(drop=True)
healthDataclean = healthDataclean.groupby(['DiagnosisCategory', 'AgeRange']).apply(gender).reset_index(drop=True)
healthDataclean = healthDataclean.groupby(['DiagnosisCategory', 'PatientGender']).apply(days).reset_index(drop=True)
healthDataclean = healthDataclean.groupby(['DiagnosisCategory']).apply(DSubCategory).reset_index(drop=True)
healthDataclean = healthDataclean.groupby(['TreatmentCategory']).apply(TSubCategory).reset_index(drop=True)
# Out:
# C:\Users\alpac\AppData\Local\Temp\ipykernel_12620\2606388213.py:32: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   healthDataclean = healthDataclean.groupby(['DiagnosisCategory']).apply(age).reset_index(drop=True)
# C:\Users\alpac\AppData\Local\Temp\ipykernel_12620\2606388213.py:33: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   healthDataclean = healthDataclean.groupby(['DiagnosisCategory', 'AgeRange']).apply(gender).reset_index(drop=True)
# C:\Users\alpac\AppData\Local\Temp\ipykernel_12620\2606388213.py:34: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   healthDataclean = healthDataclean.groupby(['DiagnosisCategory', 'PatientGender']).apply(days).reset_index(drop=True)
# C:\Users\alpac\AppData\Local\Temp\ipykernel_12620\2606388213.py:35: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   healthDataclean = healthDataclean.groupby(['DiagnosisCategory']).apply(DSubCategory).reset_index(drop=True)
# C:\Users\alpac\AppData\Local\Temp\ipykernel_12620\2606388213.py:36: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   healthDataclean = healthDataclean.groupby(['TreatmentCategory']).apply(TSubCategory).reset_index(drop=True)

# %%
healthDataclean.isnull().sum()
# did mode imputation and filled in null values, the remaining nulls aren't changed because we aren't using them
# Out:
# _id                     0
# ReferenceID             0
# ReportYear              0
# DiagnosisCategory       0
# DiagnosisSubCategory    0
# TreatmentCategory       0
# TreatmentSubCategory    0
# Determination           0
# Type                    0
# AgeRange                0
# PatientGender           0
# IMRType                 0
# DaysToReview            0
# DaysToAdopt             0
# Findings                0
# dtype: int64

# %%
healthDataclean.describe()
#updated data descriptive statistics after dropping duplicates
# Out:
#                 _id    ReportYear  DaysToReview   DaysToAdopt
# count  39413.000000  39413.000000  39413.000000  39413.000000
# mean   19715.995179   2015.210159     16.377946     37.487149
# std    11384.366446      6.064549     10.121379     21.594478
# min        1.000000   2001.000000      0.000000      1.000000
# 25%     9857.000000   2010.000000      7.000000     24.000000
# 50%    19711.000000   2016.000000     18.000000     36.000000
# 75%    29575.000000   2020.000000     21.000000     46.000000
# max    39447.000000   2025.000000    133.000000    636.000000

# %%
# --------------------------------------------
# T-test between DaysToAdopt for Male vs Female
# --------------------------------------------
from scipy.stats import ttest_ind, chi2_contingency, f_oneway

male_adopt = healthDataclean[healthDataclean['PatientGender'] == 'Male']['DaysToAdopt']
female_adopt = healthDataclean[healthDataclean['PatientGender'] == 'Female']['DaysToAdopt']
t_stat, t_p = ttest_ind(male_adopt, female_adopt, nan_policy='omit')

print("Neha - T-test:")
print(f"T-statistic = {t_stat:.4f}")
print(f"P-value = {t_p:.4f}\n")
# Out:
# Neha - T-test:
# T-statistic = 0.2735
# P-value = 0.7845

# %%
# --------------------------------------------
# Chi-square test between Determination and PatientGender
# --------------------------------------------
contingency_table = pd.crosstab(healthDataclean['Determination'], healthDataclean['PatientGender'])
chi2_stat, chi2_p, chi2_dof, _ = chi2_contingency(contingency_table)

print("Chi-square test:")
print(f"Chi2-statistic = {chi2_stat:.4f}")
print(f"P-value = {chi2_p:.4f}")
print(f"Degrees of Freedom = {chi2_dof}\n")
# Out:
# Chi-square test:
# Chi2-statistic = 11.1186
# P-value = 0.0039
# Degrees of Freedom = 2

# %%
# --------------------------------------------
# ANOVA test for DaysToReview across AgeRange groups
# --------------------------------------------
groups = [group['DaysToReview'].dropna() for _, group in healthDataclean.groupby('AgeRange')]
anova_stat, anova_p = f_oneway(*groups)

print("ANOVA test:")
print(f"F-statistic = {anova_stat:.4f}")
print(f"P-value = {anova_p:.4e}")
# Out:
# ANOVA test:
# F-statistic = 16.9822
# P-value = 1.0736e-19
